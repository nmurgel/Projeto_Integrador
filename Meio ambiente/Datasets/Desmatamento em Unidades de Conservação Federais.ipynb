# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import scipy
from scipy import stats
import scipy.stats as st

import warnings
warnings.filterwarnings("ignore")

# %%
# Desmatamento em Unidades de Conservação Federais

df = pd.read_csv('REC_FROM_GED_17462.csv', encoding='latin', delimiter=';')

# %%
df.head()
# Out:
#     Código CNUC                                    Nome da UC  \
# 0          cnuc                                            uc
# 1  0000.00.0001                               APA Anhatomirim
# 2  0000.00.1521  APA Bacia Hidrográfica do Rio Paraíba do Sul
# 3  0000.00.0007                   APA Barra do Rio Mamanguape
# 4  0000.00.0020                     APA Carste da Lagoa Santa
#
#   Monitoramento PRODES PRODES 2016 PRODES 2015 PRODES 2014 PRODES 2013  \
# 0               prodes       2016*        2015        2014        2013
# 1                  Não         NaN         NaN         NaN         NaN
# 2                  Não         NaN         NaN         NaN         NaN
# 3                  Não         NaN         NaN         NaN         NaN
# 4                  Não         NaN         NaN         NaN         NaN
#
#   PRODES 2012 PRODES 2011 PRODES 2010 PRODES 2009 PRODES 2008 PRODES 2007  \
# 0        2012        2011        2010        2009        2008        2007
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   PRODES 2006 PRODES 2005 PRODES 2004 PRODES 2003 PRODES 2002 PRODES 2001
# 0        2006        2005        2004        2003        2002        2001
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN

# %%
df.tail()
# Out:
#       Código CNUC                          Nome da UC Monitoramento PRODES  \
# 320  0000.00.1880                        REVIS de Una                  Não
# 321  0000.00.3432  REVIS do Arquipélago de Alcatrazes                  Não
# 322  0000.00.1813             REVIS do Rio dos Frades                  Não
# 323  0000.00.0278          REVIS dos Campos de Palmas                  Não
# 324  0000.00.0190                REVIS Ilha dos Lobos                  Não
#
#     PRODES 2016 PRODES 2015 PRODES 2014 PRODES 2013 PRODES 2012 PRODES 2011  \
# 320         NaN         NaN         NaN         NaN         NaN         NaN
# 321         NaN         NaN         NaN         NaN         NaN         NaN
# 322         NaN         NaN         NaN         NaN         NaN         NaN
# 323         NaN         NaN         NaN         NaN         NaN         NaN
# 324         NaN         NaN         NaN         NaN         NaN         NaN
#
#     PRODES 2010 PRODES 2009 PRODES 2008 PRODES 2007 PRODES 2006 PRODES 2005  \
# 320         NaN         NaN         NaN         NaN         NaN         NaN
# 321         NaN         NaN         NaN         NaN         NaN         NaN
# 322         NaN         NaN         NaN         NaN         NaN         NaN
# 323         NaN         NaN         NaN         NaN         NaN         NaN
# 324         NaN         NaN         NaN         NaN         NaN         NaN
#
#     PRODES 2004 PRODES 2003 PRODES 2002 PRODES 2001
# 320         NaN         NaN         NaN         NaN
# 321         NaN         NaN         NaN         NaN
# 322         NaN         NaN         NaN         NaN
# 323         NaN         NaN         NaN         NaN
# 324         NaN         NaN         NaN         NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325 entries, 0 to 324
# Data columns (total 19 columns):
# Código CNUC             325 non-null object
# Nome da UC              325 non-null object
# Monitoramento PRODES    325 non-null object
# PRODES 2016             76 non-null object
# PRODES 2015             67 non-null object
# PRODES 2014             70 non-null object
# PRODES 2013             75 non-null object
# PRODES 2012             65 non-null object
# PRODES 2011             76 non-null object
# PRODES 2010             85 non-null object
# PRODES 2009             72 non-null object
# PRODES 2008             94 non-null object
# PRODES 2007             84 non-null object
# PRODES 2006             79 non-null object
# PRODES 2005             92 non-null object
# PRODES 2004             101 non-null object
# PRODES 2003             104 non-null object
# PRODES 2002             85 non-null object
# PRODES 2001             103 non-null object
# dtypes: object(19)
# memory usage: 48.3+ KB

# %%
df[['Nome da UC']]
# Out:
#                                             Nome da UC
# 0                                                   uc
# 1                                      APA Anhatomirim
# 2         APA Bacia Hidrográfica do Rio Paraíba do Sul
# 3                          APA Barra do Rio Mamanguape
# 4                            APA Carste da Lagoa Santa
# 5                              APA Cavernas do Peruaçu
# 6                               APA Chapada do Araripe
# 7                                  APA Costa das Algas
# 8                                 APA Costa dos Corais
# 9                       APA da Bacia do Rio Descoberto
# 10                  APA da Bacia do Rio São Bartolomeu
# 11    APA da Bacia do Rio São João - Mico-Leão-Dourado
# 12                                APA da Baleia Franca
# 13               APA das Ilhas e Várzeas do Rio Paraná
# 14                   APA das Nascentes do Rio Vermelho
# 15                                      APA de Cairuçu
# 16                      APA de Cananéia-Iguape-Peruíbe
# 17   APA de Fernando de Noronha -Rocas  São Pedro ...
# 18                                  APA de Guapi-Mirim
# 19                                 APA de Guaraqueçaba
# 20                                   APA de Petrópolis
# 21                                    APA de Piaçabuçu
# 22                               APA Delta do Parnaíba
# 23                               APA do Igarapé Gelado
# 24                             APA do Planalto Central
# 25                                      APA do Tapajós
# 26                          APA dos Campos de Manicoré
# 27                                      APA Ibirapuitã
# 28                            APA Meandros do Araguaia
# 29                               APA Morro da Pedreira
# ..                                                 ...
# 295                            RESEX Marinha Cuinarana
# 296                    RESEX Marinha da Baia de Iguape
# 297                   RESEX Marinha da Lagoa do Jequiá
# 298                      RESEX Marinha de Gurupi-Piriá
# 299                             RESEX Marinha de Soure
# 300                   RESEX Marinha do Arraial do Cabo
# 301                          RESEX Marinha do Corumbau
# 302                 RESEX Marinha do Delta do Parnaíba
# 303                       RESEX Marinha Mestre Lucindo
# 304                           RESEX Marinha Mocapajuba
# 305                            RESEX Marinha Pirajubaé
# 306                           RESEX Marinha Tracuateua
# 307                       RESEX Prainha do Canto Verde
# 308                                     RESEX Renascer
# 309                                    RESEX Rio Iriri
# 310                                    RESEX Rio Unini
# 311                                    RESEX Rio Xingu
# 312                        RESEX Riozinho da Liberdade
# 313                         RESEX Riozinho do Anfrísio
# 314                             RESEX Tapajós-Arapiuns
# 315                        RESEX Terra Grande-Pracuuba
# 316                            RESEX Verde Para Sempre
# 317                  REVIS das Veredas do Oeste Baiano
# 318                                  REVIS de Boa Nova
# 319                                REVIS de Santa Cruz
# 320                                       REVIS de Una
# 321                 REVIS do Arquipélago de Alcatrazes
# 322                            REVIS do Rio dos Frades
# 323                         REVIS dos Campos de Palmas
# 324                               REVIS Ilha dos Lobos
#
# [325 rows x 1 columns]
