# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import scipy
from scipy import stats
import scipy.stats as st

import warnings
warnings.filterwarnings("ignore")

# %%
# Sistema de Análise e Monitoramento da Efetividade de Gestão - SAMGe

df = pd.read_csv('REC_FROM_GED_17461.csv', encoding='latin', delimiter=';')

# %%
df.head(3)
# Out:
#            CNUC                                            UNIDADE  \
# 0  0000.00.0006        ÁREA DE PROTEÇÃO AMBIENTAL DA BALEIA FRANCA
# 1  0000.00.0007  ÁREA DE PROTEÇÃO AMBIENTAL BARRA DO RIO MAMANG...
# 2  0000.00.3407  ÁREA DE PROTEÇÃO AMBIENTAL DOS CAMPOS DE MANICORÉ
#
#     RESULTADOS PRODUTOS E SERVIÇOS     CONTEXTO PLANEJAMENTO       INSUMOS  \
# 0          0,5         0,618386243  0,619047619   0,609139017   0,64009895
# 1  0,691558442         0,741341991  0,403061224   0,372271276  0,235821786
# 2  0,416666667                 0,5  0,458333333     0,1760424  0,014389714
#
#      PROCESSOS                   CATEGORIA             BIOMA  \
# 0  0,583333333  Área de Proteção Ambiental  Marinho-Costeiro
# 1  0,364583333  Área de Proteção Ambiental  Marinho-Costeiro
# 2  0,333333333  Área de Proteção Ambiental          Amazônia
#
#                      CR   Nota Geral Efetividade de Gestão em %
# 0  CR9 Florianópolis/SC  0,890041334                     59,34%
# ...

# %%
df.tail()
# Out:
#              CNUC                                            UNIDADE  \
# 201  0000.00.0190           REFUGIO DE VIDA SILVESTRE ILHA DOS LOBOS
# 202  0000.00.1813        REFúGIO DE VIDA SILVESTRE DO RIO DOS FRADES
# 203  0000.00.1911            REFÚGIO DE VIDA SILVESTRE DE SANTA CRUZ
# 204  0000.00.1880                   REFúGIO DE VIDA SILVESTRE DE UNA
# 205  0000.00.0219  REFUGIO DE VIDA SILVESTRE VEREDAS DO OESTE BAIANO
#
#       RESULTADOS PRODUTOS E SERVIÇOS     CONTEXTO PLANEJAMENTO       INSUMOS  \
# 201  0,828571429         0,654761905          0,5   0,441578892  0,607246857
# 202  0,488095238          0,53422619  0,476190476    0,53916545  0,618856375
# 203  0,744047619         0,537414966  0,392857143   0,433167004  0,635818286
# 204  0,446428571         0,349206349  0,214285714   0,305880322    0,4201063
# 205  0,547619048         0,411904762  0,330952381   0,355088753    0,5501015
#
#        PROCESSOS                  CATEGORIA             BIOMA  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 13 columns):
# CNUC                          206 non-null object
# UNIDADE                       206 non-null object
# RESULTADOS                    206 non-null object
# PRODUTOS E SERVIÇOS           206 non-null object
# CONTEXTO                      206 non-null object
# PLANEJAMENTO                  206 non-null object
# INSUMOS                       206 non-null object
# PROCESSOS                     206 non-null object
# CATEGORIA                     206 non-null object
# BIOMA                         206 non-null object
# CR                            206 non-null object
# Nota Geral                    206 non-null object
# Efetividade de Gestão em %    206 non-null object
# dtypes: object(13)
# memory usage: 21.0+ KB

# %%
df[['CR']].head()
# Out:
#                      CR
# 0  CR9 Florianópolis/SC
# 1       CR6 Cabedelo/PB
# 2         CR2 Manaus/AM
# 3   CR11 Lagoa Santa/MG
# 4   CR11 Lagoa Santa/MG

# %%
df['CR'].value_counts(dropna=False)
# Out:
# CR9 Florianópolis/SC     30
# CR2 Manaus/AM            29
# CR7 Porto Seguro/BA      24
# CR8 Rio de Janeiro/RJ    22
# CR3 Santarém/PA          21
# CR6 Cabedelo/PB          19
# CR4 Belém/PA             19
# CR1 Porto Velho/RO       17
# CR11 Lagoa Santa/MG      12
# CR5 Parnaíba/PI           7
# CR10 Cuiabá/MT            5
# #REF!                     1
# Name: CR, dtype: int64

# %%
Manaus = df[df.CR == 'CR2 Manaus/AM']
Manaus
# Out:
#              CNUC                                            UNIDADE  \
# 2    0000.00.3407  ÁREA DE PROTEÇÃO AMBIENTAL DOS CAMPOS DE MANICORÉ
# 18   0000.00.0038  ÁREA DE RELEVANTE INTERESSE ECOLÓGICA JAVARI B...
# 22   0000.00.0043  ÁREA DE RELEVANTE INTERESSE ECOLÓGICA PROJETO ...
# 24   0000.00.3131                       ESTAçãO ECOLóGICA ALTO MAUéS
# 25   0000.00.0051                     ESTAÇÃO ECOLÓGICA DE CARACARAÍ
# 31   0000.00.0072                     ESTAÇÃO ECOLÓGICA JUAMI-JAPURÁ
# 32   0000.00.0056                ESTAÇÃO ECOLÓGICA DE JUTAÍ-SOLIMÕES
# 36   0000.00.0060                        ESTAÇÃO ECOLÓGICA DE NIQUIÁ
# 47   0000.00.0114                      FLORESTA NACIONAL DO AMAZONAS
# 48   0000.00.0084                         FLORESTA NACIONAL DE ANAUÁ
# 50   0000.00.3409                      FLORESTA NACIONAL DO ARIPUANÃ
# 69   0000.00.0119                     FLORESTA NACIONAL DE JATUARANA
# 75   0000.00.0104                      FLORESTA NACIONAL DE PAU-ROSA
# ...

# %%
Manaus.head(3)
# Out:
#             CNUC                                            UNIDADE  \
# 2   0000.00.3407  ÁREA DE PROTEÇÃO AMBIENTAL DOS CAMPOS DE MANICORÉ
# 18  0000.00.0038  ÁREA DE RELEVANTE INTERESSE ECOLÓGICA JAVARI B...
# 22  0000.00.0043  ÁREA DE RELEVANTE INTERESSE ECOLÓGICA PROJETO ...
#
#      RESULTADOS PRODUTOS E SERVIÇOS     CONTEXTO PLANEJAMENTO       INSUMOS  \
# 2   0,416666667                 0,5  0,458333333     0,1760424  0,014389714
# 18          0,5         0,452380952  0,428571429   0,049536256    0,0001015
# 22  0,964285714         0,928571429          0,5   0,772670063  0,807249429
#
#       PROCESSOS                              CATEGORIA     BIOMA  \
# 2   0,333333333             Área de Proteção Ambiental  Amazônia
# 18        0,125  Área de Relevante Interesse Ecológico  Amazônia
# 22       0,8125  Área de Relevante Interesse Ecológico  Amazônia
#
#                CR   Nota Geral Efetividade de Gestão em %
# 2   CR2 Manaus/AM  0,407674712                     27,18%
# ...
